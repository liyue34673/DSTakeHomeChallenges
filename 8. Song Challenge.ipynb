# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc, roc_curve, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn import tree

import h2o
from h2o.frame import H2OFrame
from h2o.estimators.random_forest import H2ORandomForestEstimator
from h2o.grid.grid_search import H2OGridSearch
from h2o.estimators.gbm import H2OGradientBoostingEstimator
from h2o.estimators.stackedensemble import H2OStackedEnsembleEstimator
from __future__ import print_function
import graphviz
from collections import Counter
from sklearn.preprocessing import normalize

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_json('../DS_Challenges/Song_Challenge/song_challenge.json')
data.head()
# Out:
#            id  user_id  user_state user_sign_up_date  \
# 0  GOQMMKSQQH      122   Louisiana        2015-05-16
# 1  HWKKBQKNWI        3        Ohio        2015-05-01
# 2  DKQSXVNJDH       35  New Jersey        2015-05-04
# 3  HLHRIDQTUW      126    Illinois        2015-05-16
# 4  SUKJCSBCYW        6  New Jersey        2015-05-01
#
#                              song_played          time_played
# 0                               Hey Jude  2015-06-11 21:51:35
# 1                     We Can Work It Out  2015-06-06 16:49:19
# 2                   Back In the U.S.S.R.  2015-06-14 02:11:29
# 3                        P.s. I Love You  2015-06-08 12:26:10
# 4  Sgt. Pepper's Lonely Hearts Club Band  2015-06-28 14:57:00

# %%
data['time_played'] = pd.to_datetime(data['time_played'])
data['user_sign_up_date'] = pd.to_datetime(data['user_sign_up_date'])

# %%
data = data.set_index('id')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4000 non-null   object
#  1   user_id            4000 non-null   int64
#  2   user_state         4000 non-null   object
#  3   user_sign_up_date  4000 non-null   datetime64[ns]
#  4   song_played        4000 non-null   object
#  5   time_played        4000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 187.6+ KB

# %%
len(data['user_id'].unique())
# Out:
# 196

# %%
len(data['id'].unique())
# Out:
# 4000

# %% [markdown]
# # Question 1
#
# - What are the top 3 and the bottom 3 states in terms of number of users?
#
# - Answer:
#
#     **Top 3:** New York, California, Texas
#
#     **Bottom 3:** 'New Mexico', 'Idaho', 'North Dakota', 'Connecticut', 'Iowa', 'Rhode Island', 'Nebraska', 'Arizona', 'Kansas'

# %%
# top3
state_user_count = data.groupby('user_state')['user_id'].apply(lambda x:x.value_counts()).\
    reset_index().\
    rename(columns = {'user_id':'count'}).\
    rename(columns={'level_1':'user_id'}).\
    groupby('user_state').user_id.apply(lambda x:len(x)).\
    reset_index().\
    sort_values('user_id',ascending = False).\
    rename(columns = {'user_id':'number of users'})
state_user_count.head(3)
# Out:
#     user_state  number of users
# 25    New York               23
# 4   California               21
# 35       Texas               15

# %%
# bottom 3
state_user_count.tail(9)
# Out:
#       user_state  number of users
# 24    New Mexico                1
# 9          Idaho                1
# 27  North Dakota                1
# 6    Connecticut                1
# 12          Iowa                1
# 32  Rhode Island                1
# 22      Nebraska                1
# 2        Arizona                1
# 13        Kansas                1

# %% [markdown]
# # Question 2
# - What are the top 3 and the bottom 3 states in terms of user engagement?
#
# - Answer:
#
#     **Top 3**: Nebraska, Alaska, Mississippi
#
#     **Bottom 3**: Minnesota, Virginia, Kansas

# %% [markdown]
# Here, we define the user engagement is measured throught the average plays per user in the given state.
#
# Of course, there are other definitions, such as "average play event per hour" (see [this link](https://github.com/stasi009/TakeHomeDataChallenges/blob/master/08.SongChallenge/song_challenge.ipynb) for details).

# %%
# create temporary dataframe for play count per state
state_play_count = data.groupby(['user_state','user_id']).agg({'song_played':'count'}).\
    reset_index().\
    groupby('user_state')['song_played'].\
    sum().\
    reset_index()

# merge user count and play count
state_user_play = state_play_count.merge(state_user_count, on = 'user_state')

# calculate average play
state_user_play['average_play'] = state_user_play['song_played']/state_user_play['number of users']

# sort according to average_play
state_user_play = state_user_play.sort_values(by = 'average_play',ascending=False)

# %%
state_user_play.head(3)
# Out:
#      user_state  song_played  number of users  average_play
# 22     Nebraska           36                1     36.000000
# 1        Alaska           58                2     29.000000
# 20  Mississippi           85                3     28.333333

# %%
# bottom 3
state_user_play.tail(3)
# Out:
#    user_state  song_played  number of users  average_play
# 19  Minnesota           42                4          10.5
# 37   Virginia           17                2           8.5
# 13     Kansas            8                1           8.0

# %% [markdown]
# # Question 3
#
# - Give him a list of first-sign-up users in each state.

# %%
usersignup = data.groupby('user_state').agg({'user_sign_up_date':'min'}).reset_index()
userfirstsign = data[['user_state','user_id','user_sign_up_date']].\
                merge(usersignup,on=['user_state','user_sign_up_date'],how = 'right').\
                drop_duplicates()

# %%
userfirstsign.sort_values(by = 'user_sign_up_date',ascending=True)
# Out:
#          user_state  user_id user_sign_up_date
# 0           Alabama        5        2015-05-01
# 902           Texas        7        2015-05-01
# 814          Oregon        1        2015-05-01
# 773            Ohio        3        2015-05-01
# 729  North Carolina        2        2015-05-01
# 607      New Jersey        6        2015-05-01
# 633      New Mexico        4        2015-05-01
# 477        Michigan       13        2015-05-02
# 496       Minnesota        8        2015-05-02
# 498       Minnesota       21        2015-05-02
# 501     Mississippi       26        2015-05-02
# 651        New York       22        2015-05-02
# 466   Massachusetts       15        2015-05-02
# 655        New York       27        2015-05-02
# 657        New York       12        2015-05-02
# 658        New York       10        2015-05-02
# 824    Pennsylvania       11        2015-05-02
# 650        New York       19        2015-05-02
# 427        Maryland       18        2015-05-02
# 499     Mississippi       23        2015-05-02
# 238         Georgia       20        2015-05-02
# 242         Georgia       16        2015-05-02
# 914            Utah       29        2015-05-03
# 397        Kentucky       34        2015-05-04
# 78       California       39        2015-05-04
# 79       California       44        2015-05-04
# 170         Florida       41        2015-05-04
# 172         Florida       43        2015-05-04
# 983       Wisconsin       32        2015-05-04
# 345        Illinois       45        2015-05-05
# 425       Louisiana       50        2015-05-06
# 967   West Virginia       60        2015-05-07
# 884       Tennessee       70        2015-05-08
# 864  South Carolina       64        2015-05-08
# 69         Arkansas       78        2015-05-08
# 539        Missouri       85        2015-05-09
# 21           Alaska      106        2015-05-12
# 358         Indiana      102        2015-05-12
# 47          Arizona      105        2015-05-12
# 949      Washington      125        2015-05-16
# 791        Oklahoma      119        2015-05-16
# 154     Connecticut      127        2015-05-16
# 571        Nebraska      134        2015-05-16
# 747    North Dakota      135        2015-05-17
# 947        Virginia      142        2015-05-17
# 366            Iowa      178        2015-05-19
# 837    Rhode Island      174        2015-05-19
# 122        Colorado      166        2015-05-19
# 389          Kansas      177        2015-05-19
# 319           Idaho      165        2015-05-19
# 119        Colorado      173        2015-05-19

# %% [markdown]
# # Question 4
#
# - Build a function that takes as an input any of the songs in the data and returns the most likely song to be listened next
# - *(Song Recommendation Model)*
#
# There should be a lot of different methods for this question. The simplest method is to choose the most popular songs. In addition, k-nearest neighbor (KNN) method can also be used. More advancely, collaborative filtering method can be implemented.
#
# Here, I implement a simple version of `collaborative filtering` algorithm for song recommendation. More specifically, the similarity of two songs is calculate using the number of users whole listen them together.

# %%
data = data.reset_index()

# %% [markdown]
# ### method 1: choose the most popular songs

# %%
## but this doesn't work well, since almost every user has read 'Come Together' before, 
## so this book has been served as the recommended book for many books
def song_recommendation(data, songname):
    """ function to recommend a song in terms of an input song name """
    tmp = data.loc[data['song_played']==songname]
    tmp = data.loc[data['song_played']==songname]
    userid = tmp['user_id'].to_list()
    song_recommend = data.loc[data['user_id'].\
                     isin(userid)].\
                     groupby('song_played')['id'].\
                     count().reset_index().\
                     sort_values(by = 'id',ascending = False).\
                     head(1)['song_played'].values[0]
    return song_recommend

# %%
song_recommendation(data,'ANYTIME AT ALL')
# Out:
# 'Come Together'

# %%
print('input song\trecommened song')
print("*****************")
for song in data['song_played'].unique():
    recommend = song_recommendation(data,song)
    print(f'{song}\t{recommend}')
# Out:
# input song	recommened song
# *****************
# Hey Jude	Come Together
# We Can Work It Out	Come Together
# Back In the U.S.S.R.	Come Together
# P.s. I Love You	Come Together
# Sgt. Pepper's Lonely Hearts Club Band	Come Together
# Sgt. Pepper Inner Groove	Revolution
# Hello Goodbye	Come Together
# Cry For A Shadow	Come Together
# Revolution	Come Together
# Let It Be	Come Together
# I Feel Fine	Come Together
# The Fool On The Hill	Come Together
# Get Back	Come Together
# Come Together	Come Together
# She Loves You	Revolution
# While My Guitar Gently Weeps	Come Together
# Here Comes The Sun	Come Together
# A Day In The Life	Come Together
# Getting Better	Come Together
# Baby You're A Rich Man	Come Together
# The Ballad Of John And Yoko	Come Together
# Lucy In The Sky With Diamonds	Come Together
# Don't Let Me Down	Come Together
# Reprise / Day in the Life	Come Together
# Maxwell's Silver Hammer	Come Together
# Across The Universe	Revolution
# Ob-la-di, Ob-la-da	Come Together
# Yesterday	Come Together
# Fixing A Hole	Come Together
# OH DARLING	Come Together
# Birthday	Come Together
# A Saturday Club Xmas/Crimble Medley	Back In the U.S.S.R.
# Got To Get You Into My Life	Come Together
# Wild Honey Pie	Come Together
# IN MY LIFE	Come Together
# Strawberry Fields Forever	Come Together
# Twist and Shout	Come Together
# I Saw Her Standing There	Come Together
# Helter Skelter	Come Together
# Something	Come Together
# Eleanor Rigby	Come Together
# Things We Said Today	Come Together
# With a Little Help From My Friends	Come Together
# You Never Give Me Your Money	Come Together
# YOUR MOTHER SHOULD KNOW	Revolution
# The Long And Winding Road	Come Together
# Sun King	Revolution
# I've Got A Feeling	Come Together
# Eight Days A Week	Come Together
# Day Tripper	Revolution
# Roll Over Beethoven	Come Together
# I Am the Walrus	Revolution
# Lady Madonna	Come Together
# Good Day Sunshine	Come Together
# Blackbird	Come Together
# ROCK AND ROLL MUSIC	Get Back
# Can't Buy Me Love	Come Together
# Golden Slumbers	Come Together
# Magical Mystery Tour	Come Together
# I Want You (She's So Heavy)	Come Together
# She's Leaving Home	Come Together
# Yellow Submarine	Come Together
# THE CONTINUING STORY OF BUNG	Come Together
# BAD BOY	Come Together
# A Hard Day's Night	Come Together
# All My Loving	Come Together
# You're Going To Lose That Girl	Come Together
# Everybody's Got Something To Hide Except Me And My Monk	Revolution
# Ticket to Ride	Revolution
# Drive My Car	Come Together
# The Word	Come Together
# I'm A Loser	Come Together
# Help!	Come Together
# Dear Prudence	Revolution
# All You Need Is Love	Come Together
# Paperback Writer	Revolution
# I'll Follow The Sun	Get Back
# Rocky Raccoon	Revolution
# NOWHERE MAN	Come Together
# Sgt. Pepper's Lonely Hearts Club Band (Reprise)	Revolution
# I've Just Seen A Face	Come Together
# Penny Lane	Revolution
# SHE'S A WOMAN	Come Together
# And Your Bird Can Sing	Come Together
# Two Of Us	Come Together
# From Me To You	Come Together
# Please Please Me	Come Together
# GIRL	Come Together
# IT WON'T BE LONG	Revolution
# Norwegian Wood	Come Together
# Love Me Do	Come Together
# I Want To Hold Your Hand	Come Together
# LITTLE CHILD	Come Together
# ANYTIME AT ALL	Come Together
# I'm Down	Come Together
# Lovely Rita	Get Back
# When I'm 64	Come Together

# %% [markdown]
# ### method 2: collaborative filtering algorithm

# %%
# step 1: build the song-user matrix

def count_by_song(df):
    """ All data in df comes from the same song """
    return pd.Series(Counter(df.user_id))

song_user = data.groupby(['song_played']).apply(count_by_song).unstack().fillna(0).astype(int)

# each row is a song
# each column represents a user
# [i,j] represents number of times user 'j' plays song 'i'

song_user.head()
# Out:
#                                      1    2    3    4    5    6    7    8    \
# song_played
# A Day In The Life                      0    0    1    3    0    2    0    0
# A Hard Day's Night                     0    0    0    0    0    1    0    0
# A Saturday Club Xmas/Crimble Medley    0    0    0    0    0    0    0    0
# ANYTIME AT ALL                         0    0    0    0    0    0    0    0
# Across The Universe                    0    0    0    1    0    0    0    0
#
#                                      9    10   ...  191  192  193  194  195  \
# song_played                                    ...
# A Day In The Life                      0    0  ...    0    0    3    3    0
# A Hard Day's Night                     1    0  ...    0    0    0    0    1
# A Saturday Club Xmas/Crimble Medley    0    0  ...    0    0    0    0    0
# ANYTIME AT ALL                         0    0  ...    0    0    0    0    0
# Across The Universe                    0    0  ...    0    0    0    0    0
#
#                                      196  197  198  199  200
# song_played
# A Day In The Life                      2    0    0    2    0
# A Hard Day's Night                     0    0    0    0    0
# A Saturday Club Xmas/Crimble Medley    0    0    0    0    0
# ANYTIME AT ALL                         0    0    0    0    0
# Across The Universe                    0    0    0    0    0
#
# [5 rows x 196 columns]

# %%
# Step 2: build song-song similarity matrix

# normalize each song's vector to have unit norm
# which simplifies 'cosine similarity' to dot-product of two vectors
song_user_norm = normalize(song_user, axis=1)

# songs_similarity is a [S,S] matrix, where 'S' is #songs
# the higher songs_similarity[i,j] indicates the more similar between song[i] and song[j]
similarity = np.dot(song_user_norm,song_user_norm.T)

# transform np.ndarray to pd.DataFrame
similarity_df = pd.DataFrame(similarity, index=song_user.index, columns=song_user.index)
similarity_df
# Out:
# song_played                          A Day In The Life  A Hard Day's Night  \
# song_played
# A Day In The Life                             1.000000            0.246021
# A Hard Day's Night                            0.246021            1.000000
# A Saturday Club Xmas/Crimble Medley           0.067651            0.000000
# ANYTIME AT ALL                                0.108483            0.000000
# Across The Universe                           0.192538            0.100000
# ...                                                ...                 ...
# YOUR MOTHER SHOULD KNOW                       0.033826            0.000000
# Yellow Submarine                              0.331593            0.050000
# Yesterday                                     0.339179            0.195468
# You Never Give Me Your Money                  0.079727            0.074536
# You're Going To Lose That Girl                0.000000            0.000000
#
# song_played                          A Saturday Club Xmas/Crimble Medley  \
# song_played
# A Day In The Life                                               0.067651
# A Hard Day's Night                                              0.000000
# A Saturday Club Xmas/Crimble Medley                             1.000000
# ANYTIME AT ALL                                                  0.000000
# Across The Universe                                             0.000000
# ...                                                                  ...
# YOUR MOTHER SHOULD KNOW                                         0.000000
# Yellow Submarine                                                0.000000
# Yesterday                                                       0.000000
# You Never Give Me Your Money                                    0.000000
# You're Going To Lose That Girl                                  0.000000
#
# song_played                          ANYTIME AT ALL  Across The Universe  \
# song_played
# A Day In The Life                          0.108483             0.192538
# A Hard Day's Night                         0.000000             0.100000
# A Saturday Club Xmas/Crimble Medley        0.000000             0.000000
# ANYTIME AT ALL                             1.000000             0.000000
# Across The Universe                        0.000000             1.000000
# ...                                             ...                  ...
# YOUR MOTHER SHOULD KNOW                    0.000000             0.000000
# Yellow Submarine                           0.000000             0.000000
# Yesterday                                  0.146845             0.043437
# You Never Give Me Your Money               0.000000             0.000000
# You're Going To Lose That Girl             0.000000             0.000000
#
# song_played                          All My Loving  All You Need Is Love  \
# song_played
# A Day In The Life                         0.341760              0.322896
# A Hard Day's Night                        0.136931              0.111803
# A Saturday Club Xmas/Crimble Medley       0.000000              0.000000
# ANYTIME AT ALL                            0.154303              0.094491
# Across The Universe                       0.091287              0.000000
# ...                                            ...                   ...
# YOUR MOTHER SHOULD KNOW                   0.144338              0.088388
# Yellow Submarine                          0.273861              0.111803
# Yesterday                                 0.178437              0.291386
# You Never Give Me Your Money              0.068041              0.166667
# You're Going To Lose That Girl            0.000000              0.000000
#
# song_played                          And Your Bird Can Sing   BAD BOY  \
# song_played
# A Day In The Life                                  0.138092  0.223237
# A Hard Day's Night                                 0.000000  0.000000
# A Saturday Club Xmas/Crimble Medley                0.000000  0.000000
# ANYTIME AT ALL                                     0.109109  0.000000
# Across The Universe                                0.000000  0.000000
# ...                                                     ...       ...
# YOUR MOTHER SHOULD KNOW                            0.102062  0.000000
# Yellow Submarine                                   0.258199  0.000000
# Yesterday                                          0.112154  0.064752
# You Never Give Me Your Money                       0.000000  0.111111
#
# song_played                          Yellow Submarine  Yesterday  \
# song_played
# A Day In The Life                            0.331593   0.339179
# A Hard Day's Night                           0.050000   0.195468
# A Saturday Club Xmas/Crimble Medley          0.000000   0.000000
# ANYTIME AT ALL                               0.000000   0.146845
# Across The Universe                          0.000000   0.043437
# ...                                               ...        ...
# YOUR MOTHER SHOULD KNOW                      0.079057   0.068680
# Yellow Submarine                             1.000000   0.195468
# Yesterday                                    0.195468   1.000000
# You Never Give Me Your Money                 0.074536   0.259010
# You're Going To Lose That Girl               0.000000   0.000000
#
# song_played                          You Never Give Me Your Money  \
# song_played
# A Day In The Life                                        0.079727
# A Hard Day's Night                                       0.074536
# A Saturday Club Xmas/Crimble Medley                      0.000000
# ANYTIME AT ALL                                           0.000000
# Across The Universe                                      0.000000
# ...                                                           ...
# YOUR MOTHER SHOULD KNOW                                  0.000000
# Yellow Submarine                                         0.074536
# Yesterday                                                0.259010
# You Never Give Me Your Money                             1.000000
# You're Going To Lose That Girl                           0.000000
#
# song_played                          You're Going To Lose That Girl
# song_played
# A Day In The Life                                               0.0
# A Hard Day's Night                                              0.0
# A Saturday Club Xmas/Crimble Medley                             0.0
# ANYTIME AT ALL                                                  0.0
# Across The Universe                                             0.0
# ...                                                             ...
# YOUR MOTHER SHOULD KNOW                                         0.0
# Yellow Submarine                                                0.0
# Yesterday                                                       0.0
# You Never Give Me Your Money                                    0.0
# You're Going To Lose That Girl                                  1.0
#
# [97 rows x 97 columns]

# %%
similarity_df.loc['A Day In The Life'].sort_values(ascending = False)[1:2].reset_index()
# Out:
#   song_played  A Day In The Life
# 0  Revolution           0.594266

# %%
# Step 3: find the top-k most similar songs

def find_topk(similarity, song_name, k=1):
    tmp = similarity.loc[song_name].sort_values(ascending = False)[1:k+1].reset_index()
    tmp = tmp.rename(columns = {'song_played':'song_recommended','A Day In The Life':'similarity'})
    return tmp

# %%
# an example of k=10, song_name = 'A Day In The Life'
find_topk(similarity = similarity_df, song_name = 'A Day In The Life', k=10)
# Out:
#                 song_recommended  similarity
# 0                     Revolution    0.594266
# 1                  Come Together    0.576682
# 2                       Get Back    0.552443
# 3   While My Guitar Gently Weeps    0.509397
# 4           Back In the U.S.S.R.    0.497328
# 5                      Let It Be    0.496184
# 6             Here Comes The Sun    0.493598
# 7                  Hello Goodbye    0.491431
# 8                       Hey Jude    0.490221
# 9  Lucy In The Sky With Diamonds    0.485512

# %%
# step 4 find top K most similar of each song
def most_similar_songs(s,topk):
    # [0] must be itself
    similar_ones = s.sort_values(ascending=False)[1:topk+1].index.values
    return pd.Series(similar_ones,index = ["similar#{}".format(i) for i in range(1,topk+1)])

pd.set_option('display.max_rows',100)
similarity_df.apply(most_similar_songs,topk=2,axis=1)
# Out:
#                                                                                             similar#1  \
# song_played
# A Day In The Life                                                                          Revolution
# A Hard Day's Night                                                                      Come Together
# A Saturday Club Xmas/Crimble Medley                                                              GIRL
# ANYTIME AT ALL                                                                      Can't Buy Me Love
# I'll Follow The Sun                                  Got To Get You Into My Life
# I'm A Loser                                                          When I'm 64
# I'm Down                                                      She's Leaving Home
# I've Got A Feeling                                         I've Just Seen A Face
# I've Just Seen A Face                                              Come Together
# IN MY LIFE                                                             Let It Be
# IT WON'T BE LONG                                                   Rocky Raccoon
# LITTLE CHILD                                                         I'm A Loser
# Lady Madonna                                             YOUR MOTHER SHOULD KNOW
# Let It Be                                                             Revolution
# Love Me Do                                                           When I'm 64
# Lovely Rita                                                     Please Please Me
# Lucy In The Sky With Diamonds                                         Revolution
# Magical Mystery Tour                                               Eleanor Rigby
# Maxwell's Silver Hammer                                               Revolution
# NOWHERE MAN                                                           Love Me Do
# Norwegian Wood                                                   I Am the Walrus
# OH DARLING                                                             Let It Be
# Ob-la-di, Ob-la-da                                                    Revolution
# P.s. I Love You                                                   Wild Honey Pie
# Paperback Writer                                     Got To Get You Into My Life
# Penny Lane                                                              Get Back
# Please Please Me                                            Things We Said Today
# ROCK AND ROLL MUSIC                                               Helter Skelter
# Reprise / Day in the Life                           While My Guitar Gently Weeps
# Revolution                                                              Get Back
# Rocky Raccoon                                       While My Guitar Gently Weeps
# Roll Over Beethoven                                               From Me To You
# SHE'S A WOMAN                                                         IN MY LIFE
# Sgt. Pepper Inner Groove                                        Cry For A Shadow
# Sgt. Pepper's Lonely Hearts Club Band                             Getting Better
# Sgt. Pepper's Lonely Hearts Club Band (Reprise)               We Can Work It Out
# She Loves You                                               Back In the U.S.S.R.
# She's Leaving Home                                               Golden Slumbers
# Something                                                             Revolution
# Strawberry Fields Forever                                             Revolution
# Sun King                                                               Something
# THE CONTINUING STORY OF BUNG                           Strawberry Fields Forever
# The Ballad Of John And Yoko                                            Something
# The Fool On The Hill                                               Come Together
# The Long And Winding Road                                  I've Just Seen A Face
# The Word                                                Sgt. Pepper Inner Groove
# Things We Said Today                                You Never Give Me Your Money
# Ticket to Ride                                                        Revolution
# Twist and Shout                                                A Day In The Life
# Two Of Us                                                   Back In the U.S.S.R.
# We Can Work It Out                                                     Let It Be
# When I'm 64                                                I've Just Seen A Face
# While My Guitar Gently Weeps                                           Let It Be
# Wild Honey Pie                                                We Can Work It Out
# With a Little Help From My Friends                                    Revolution
# YOUR MOTHER SHOULD KNOW                                            Hello Goodbye
# Yellow Submarine                                       Reprise / Day in the Life
# Yesterday                                                          Come Together
# You Never Give Me Your Money                                       She Loves You
# You're Going To Lose That Girl                                     Fixing A Hole

# %% [markdown]
# # Question 5
#
# - How would you set up a test to check whether your model works well and is improving engagement?

# %% [markdown]
# **Answer:**
#
# We need to perform a A/B test ([reference](https://github.com/stasi009/TakeHomeDataChallenges/blob/master/08.SongChallenge/song_challenge.ipynb)):
#
# * randomly split users into two groups, one Control group and one Experiment group
# * Control group has no recommendation strategy
# * Experiment group recommend the next song
# * after running some time, perform a one-tailed t-test on 'average #play per user'
#     - $H_0$: population 'average #play per user' is same in two groups
#     - $H_a$: experiment group's population 'average #play per user' is higher than control group's
